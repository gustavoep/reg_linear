# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoep/reg_linear/blob/main/Reg_Linear_Multipla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   REGRESSÃO LINEAR MÚLTIPLA

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = [[0.0108, 0.0107,0.011,0.013,0.015], [0.015, 0.014, 0.014,0.014,0.014], [0.015, 0.014,0.013,0.014,0.014], [0.014,0.013,0.014,0.016,0.014], [0.013, 0.010,0.010,0.014,0.013]]
y = [2.01, 2.44, 2.62, 2.18, 2.71]
x, y = np.array(x), np.array(y)
y
# Out:
# array([2.01, 2.44, 2.62, 2.18, 2.71])

# %%
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 1.0

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: 5.403210920327507

# %%
print(f"coefficients: {model.coef_}")
# Out:
# coefficients: [  84.43769218  126.18813621 -180.          -24.68708581 -223.62792918]

# %%
y_pred = model.predict(x)
print(f"predicted response:\n{y_pred}")
# Out:
# predicted response:
# [2.01 2.44 2.62 2.18 2.71]

# %%
x_new = np.arange(10).reshape((-1, 2))
y_new = model.predict(x_new)
y_new
# Out:
# array([ 5.77760476,  7.18179502,  8.58598528,  9.99017554, 11.3943658 ])

# %%
plt.plot(x, y)
plt.plot(x, y, 'o')
plt.show()
